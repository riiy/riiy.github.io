# %%
#	Word	count	on	1st	Chapter	of	the	Book	using	PySpark
#	import	regex	module
import	re
#	import	add	from	operator	module
from operator import add
file_in = sc.textFile('/home/zhoubo/k-vim/vimrc')
# count lines
print('######number of lines in file: %s' % file_in.count())
# add up lengths of each line
chars = file_in.map(lambda s: len(s)).reduce(add)
print('#####number of characters in file: %s' % chars)
# words from the impofile
words = file_in.flatMap(lambda line:re.split('\W+', line.lower().strip()))
# get words from the input file
words = words.filter(lambda x: len(x) >3)
# set count 1 per word
words = words.map(lambda w: (w, 1))
# reduce phase - sum count all the words
words = words.reduceByKey(add)
words = words.map(lambda x:(x[1], x[0])).sortByKey(False)
# Out:
# ######number of lines in file: 690
# #####number of characters in file: 15102

# %%
words.take(20)
# Out:
# [(38, u'nnoremap'),
#  (33, u'leader'),
#  (22, u'autocmd'),
#  (18, u'endif'),
#  (16, u'noremap'),
#  (15, u'silent'),
#  (14, u'filetype'),
#  (12, u'call'),
#  (12, u'settings'),
#  (11, u'number'),
#  (10, u'when'),
#  (10, u'highlight'),
#  (9, u'buffer'),
#  (9, u'vimrc'),
#  (9, u'inoremap'),
#  (8, u'indent'),
#  (8, u'line'),
#  (8, u'underline'),
#  (8, u'mode'),
#  (8, u'relativenumber')]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#
def histogram(words):
    count = map(lambda x: x[1],	words)
    word = map(lambda x: x[0], words)
    plt.barh(range(len(count)),	count,color	= 'grey')
    plt.yticks(range(len(count)), word)
words =	words.map(lambda x:(x[1], x[0]))
words.take(25)
histogram(words.take(25))
# Out:
# /home/zhoubo/.anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
